# %%
# !pip install -Uqq fastbook
#!pip install transformers
import fastbook
fastbook.setup_book()

# %%
from fastbook import *
from IPython.display import display,HTML

# %%
from fastai.text.all import *
import pandas as pd

# %%
# Get data set
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/CleanSenateTweets.csv')

# %%
df.head()
# Out:
#    Unnamed: 0               Office            Name       Party TwitterHandle  \
# 0           0  U.S. Senate Alabama  Richard Shelby  Republican    @SenShelby
# 1           1  U.S. Senate Alabama  Richard Shelby  Republican    @SenShelby
# 2           2  U.S. Senate Alabama  Richard Shelby  Republican    @SenShelby
# 3           3  U.S. Senate Alabama  Richard Shelby  Republican    @SenShelby
# 4           4  U.S. Senate Alabama  Richard Shelby  Republican    @SenShelby
#
#     username  \
# 0  SenShelby
# 1  SenShelby
# 2  SenShelby
# 3  SenShelby
# 4  SenShelby
#
#                                                                                                                                                                                                                                                                                           tweet  \
# ...

# %%
txt = df.loc[2:2,'tweet']
print(txt)
# Out:
# 2    Today, my colleagues and I on the Appropriations Committee advanced three important bills that contain funding for #Alabama priorities, including resources for water infrastructure projects, farmers in rural communities, and assistance for our veterans.   https://t.co/7lExGFyF0a
# Name: tweet, dtype: object

# %%
spacy = WordTokenizer()
toks = first(spacy([txt]))
print(coll_repr(toks, 30))
# Out:
# (#52) ['2','   ','Today',',','my','colleagues','and','I','on','the','Appropriations','Committee','advanced','three','important','bills','that','contain','funding','for','#','Alabama','priorities',',','including','resources','for','water','infrastructure','projects'...]

# %%
tkn = Tokenizer(spacy)
print(coll_repr(tkn(txt), 31))
# Out:
# (#1) ['Today, my colleagues and I on the Appropriations Committee advanced three important bills that contain funding for #Alabama priorities, including resources for water infrastructure projects, farmers in rural communities, and assistance for our veterans.   https://t.co/7lExGFyF0a']

# %%
coll_repr(tkn(txt), 31)
# Out:
# "(#1) ['Today, my colleagues and I on the Appropriations Committee advanced three important bills that contain funding for #Alabama priorities, including resources for water infrastructure projects, farmers in rural communities, and assistance for our veterans.   https://t.co/7lExGFyF0a']"

# %%
dblock = DataBlock()

# %%
dsets = dblock.datasets(df)

# %%
dsets[0:5]
# Out:
# [(Pandas(Index=0, _1=(['xxbos', 'xxmaj', 'democratic'], ['xxbos', 'xxmaj', 'our', 'end', '-', 'of', '-', 'quarter', 'fundraising', 'deadline', 'is', 'coming', 'up', 'fast', ',', 'and', 'we', 'need', 'your', 'help', '.', 'xxmaj', 'the', 'dollar', 'amount', 'is', 'n’t', 'important', '—', 'it', '’s', 'about', 'showing', 'how', 'many', 'people', 'are', 'with', 'us', 'on', 'this', 'mission', '.', 'xxmaj', 'can', 'i', 'count', 'on', 'you', 'to', 'chip', 'in', 'to', 'our', 'people', '-', 'powered', 'campaign', 'today', '?', 'https', ':', '/', '/', 't.co', '/', 'tzghkuecyd'])),
# ...

# %%
dsets.train[0]
# Out:
# (0    ()
#  Name: 4, dtype: object, 0    ()
#  Name: 4, dtype: object)

# %%
def get_x(r): return r['Party']
def get_y(r): return r['tweet']
dblock = DataBlock(get_x = get_x, get_y = get_y)
dsets = dblock.datasets(df)
dsets.train[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-330a7a788369> in <module>()
#       2 def get_y(r): return r['tweet']
#       3 dblock = DataBlock(get_x = get_x, get_y = get_y)
# ----> 4 dsets = dblock.datasets(df)
#       5 dsets.train[0]
#
# /usr/local/lib/python3.7/dist-packages/fastai/data/block.py in datasets(self, source, verbose)
#     108         splits = (self.splitter or RandomSplitter())(items)
#     109         pv(f"{len(splits)} datasets of sizes {','.join([str(len(s)) for s in splits])}", verbose)
# --> 110         return Datasets(items, tfms=self._combine_type_tfms(), splits=splits, dl_type=self.dl_type, n_inp=self.n_inp, verbose=verbose)
#     111
#     112     def dataloaders(self, source, path='.', verbose=False, **kwargs):
#
# ...

# %%
stream = "In this chapter, we will go back over the example of classifying movie reviews we studied in chapter 1 and dig deeper under the surface. First we will look at the processing steps necessary to convert text into numbers and how to customize it. By doing this, we'll have another example of the PreProcessor used in the data block API.\nThen we will study how we build a language model and train it for a while."
tokens = tkn(stream)
bs,seq_len = 6,15
d_tokens = np.array([tokens[i*seq_len:(i+1)*seq_len] for i in range(bs)])
df = pd.DataFrame(d_tokens)
display(HTML(df.to_html(index=False,header=None)))
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>xxbos</td>
#       <td>xxmaj</td>
#       <td>in</td>
#       <td>this</td>
#       <td>chapter</td>
#       <td>,</td>
#       <td>we</td>
#       <td>will</td>
#       <td>go</td>
#       <td>back</td>
#       <td>over</td>
#       <td>the</td>
#       <td>example</td>
#       <td>of</td>
#       <td>classifying</td>
#     </tr>
#     <tr>
#       <td>movie</td>
#       <td>reviews</td>
#       <td>we</td>
#       <td>studied</td>
#       <td>in</td>
#       <td>chapter</td>
#       <td>1</td>
#       <td>and</td>
#       <td>dig</td>
#       <td>deeper</td>
#       <td>under</td>
#       <td>the</td>
#       <td>surface</td>
#       <td>.</td>
#       <td>xxmaj</td>
#     </tr>
#     <tr>
#       <td>first</td>
#       <td>we</td>
#       <td>will</td>
#       <td>look</td>
#       <td>at</td>
#       <td>the</td>
#       <td>processing</td>
#       <td>steps</td>
#       <td>necessary</td>
# ...

# %%
bs,seq_len = 6,5
d_tokens = np.array([tokens[i*15:i*15+seq_len] for i in range(bs)])
df = pd.DataFrame(d_tokens)
display(HTML(df.to_html(index=False,header=None)))
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>xxbos</td>
#       <td>xxmaj</td>
#       <td>in</td>
#       <td>this</td>
#       <td>chapter</td>
#     </tr>
#     <tr>
#       <td>movie</td>
#       <td>reviews</td>
#       <td>we</td>
#       <td>studied</td>
#       <td>in</td>
#     </tr>
#     <tr>
#       <td>first</td>
#       <td>we</td>
#       <td>will</td>
#       <td>look</td>
#       <td>at</td>
#     </tr>
#     <tr>
#       <td>how</td>
#       <td>to</td>
#       <td>customize</td>
#       <td>it</td>
#       <td>.</td>
#     </tr>
#     <tr>
#       <td>of</td>
#       <td>the</td>
#       <td>preprocessor</td>
#       <td>used</td>
#       <td>in</td>
#     </tr>
#     <tr>
#       <td>will</td>
#       <td>study</td>
#       <td>how</td>
#       <td>we</td>
#       <td>build</td>
#     </tr>
#   </tbody>
# </table>

# %%
bs,seq_len = 6,5
d_tokens = np.array([tokens[i*15+seq_len:i*15+2*seq_len] for i in range(bs)])
df = pd.DataFrame(d_tokens)
display(HTML(df.to_html(index=False,header=None)))
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>,</td>
#       <td>we</td>
#       <td>will</td>
#       <td>go</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <td>chapter</td>
#       <td>1</td>
#       <td>and</td>
#       <td>dig</td>
#       <td>deeper</td>
#     </tr>
#     <tr>
#       <td>the</td>
#       <td>processing</td>
#       <td>steps</td>
#       <td>necessary</td>
#       <td>to</td>
#     </tr>
#     <tr>
#       <td>xxmaj</td>
#       <td>by</td>
#       <td>doing</td>
#       <td>this</td>
#       <td>,</td>
#     </tr>
#     <tr>
#       <td>the</td>
#       <td>data</td>
#       <td>block</td>
#       <td>xxup</td>
#       <td>api</td>
#     </tr>
#     <tr>
#       <td>a</td>
#       <td>language</td>
#       <td>model</td>
#       <td>and</td>
#       <td>train</td>
#     </tr>
#   </tbody>
# </table>

# %%
bs,seq_len = 6,5
d_tokens = np.array([tokens[i*15+10:i*15+15] for i in range(bs)])
df = pd.DataFrame(d_tokens)
display(HTML(df.to_html(index=False,header=None)))
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>over</td>
#       <td>the</td>
#       <td>example</td>
#       <td>of</td>
#       <td>classifying</td>
#     </tr>
#     <tr>
#       <td>under</td>
#       <td>the</td>
#       <td>surface</td>
#       <td>.</td>
#       <td>xxmaj</td>
#     </tr>
#     <tr>
#       <td>convert</td>
#       <td>text</td>
#       <td>into</td>
#       <td>numbers</td>
#       <td>and</td>
#     </tr>
#     <tr>
#       <td>we</td>
#       <td>'ll</td>
#       <td>have</td>
#       <td>another</td>
#       <td>example</td>
#     </tr>
#     <tr>
#       <td>.</td>
#       <td>\n</td>
#       <td>xxmaj</td>
#       <td>then</td>
#       <td>we</td>
#     </tr>
#     <tr>
#       <td>it</td>
#       <td>for</td>
#       <td>a</td>
#       <td>while</td>
#       <td>.</td>
#     </tr>
#   </tbody>
# </table>

# %%
path = Path'/content/gdrive/MyDrive/Colab Notebooks/ProjectFiles/'
dls = DataBlock(
    blocks=(TextBlock.from_folder(path),CategoryBlock),
    get_y = parent_label,
    get_items=partial(get_text_files, folders=['train', 'test']),
    splitter=GrandparentSplitter(valid_name='test')
).dataloaders(path)

# %%
data_dir = Path
data_path = Path(data_dir, 'CleanSenateTweets.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-bed20b105113> in <module>()
#       1 data_dir = Path
# ----> 2 data_path = Path(data_dir, 'CleanSenateTweets.csv')
#
# /usr/lib/python3.7/pathlib.py in __new__(cls, *args, **kwargs)
#    1025         if cls is Path:
#    1026             cls = WindowsPath if os.name == 'nt' else PosixPath
# -> 1027         self = cls._from_parts(args, init=False)
#    1028         if not self._flavour.is_supported:
#    1029             raise NotImplementedError("cannot instantiate %r on your system"
#
# /usr/lib/python3.7/pathlib.py in _from_parts(cls, args, init)
#     672         # right flavour.
#     673         self = object.__new__(cls)
# --> 674         drv, root, parts = self._parse_args(args)
#     675         self._drv = drv
#     676         self._root = root
#
# ...
